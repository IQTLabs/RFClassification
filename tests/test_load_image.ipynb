# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# function to load array files as images
def plot_image(data, dim, dpi):
    fig = plt.figure(figsize=dim, dpi=dpi)
    if len(data.shape) == 2:   # spectrogram - 2D data
        plt.pcolormesh(data, cmap='Greys', vmin=data_norm.min(), vmax=data_norm.max())
    elif len(data.shape) == 1: # psd - 1D data
        plt.plot(data)
        plt.show()

# %%
file_path = '/home/kzhou/main/Features/ARR_PSD_1024_2022-06-29/WIFI_PSD_AIR_ON_1024_2022-06-29.npy'

# %%
test = np.load(file_path, allow_pickle=True).item()
len(test['feat'][1].shape)
# Out:
# 1

# %%
plot_image(test['feat'][1], (5,5), 200)
plt.show()
# len(test['feat'][20].shape)

# %% [markdown]
# ## Test Load Images as 3 Channel Data

# %%
import cv2
import os

# %%
image_path = '../../Features/testtest/IMG_SPEC_512_20/'
files = os.listdir(image_path)
# test_load = cv2.imread('g4g.png')

# %%
test = cv2.imread(image_path+files[0])

# %%
test.shape
# Out:
# (224, 224, 3)

# %%
cv2.imshow('image', test)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 cv2.imshow('image', test)
#
# error: OpenCV(4.6.0) /tmp/pip-install-7so9yhqw/opencv-python/opencv/modules/highgui/src/window.cpp:1267: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'
